# %%
import numpy as np

# %%
inputs=np.array([
 [1,2],
 [3,4],
 [5,6]
],dtype=float)
targets=np.array([
    [7],
    [8],
    [9]
],dtype=float)

# %%
## normalize data
inputs = inputs / np.max(inputs, axis=0)
targets = targets / 100.0

# %%
print(inputs)
print(targets)
# Out:
# [[0.2        0.33333333]
#  [0.6        0.66666667]
#  [1.         1.        ]]
# [[0.07]
#  [0.08]
#  [0.09]]

# %%
def activate(x):## sigmoid
    return 1/(1+np.exp(-x))
def activate_derivative(x):
    return x*(1-x)

# %%
## example for transpose
print(input.T)
# Out:
# [[1. 3. 5.]
#  [2. 4. 6.]]

# %%
num_input_features = inputs.shape[1]   # 2
num_hidden_neurons = 3
num_outputs = targets.shape[1]

# %%
epoch=1000
training_factor=0.2 ## eta

# %%
## input to hidden
weights_input_to_hidden = np.random.uniform(size=(num_input_features, num_hidden_neurons))
bias_hidden = np.random.uniform(size=(1, num_hidden_neurons))

# %%
print(weights_input_to_hidden)
print(bias_hidden)
# Out:
# [[0.36812749 0.2700826  0.27476663]
#  [0.89201574 0.34724169 0.52871744]
#  [0.24612261 0.78153062 0.54940882]]
# [[0.31201952 0.96118001 0.9268288 ]]

# %%
weights_hidden_to_output=np.random.uniform(size=(num_hidden_neurons,num_outputs))
bias_output=np.random.uniform(size=(1,num_outputs))

# %%
print(weights_hidden_to_output)
print(bias_output)
# Out:
# [[0.1910266 ]
#  [0.91822115]
#  [0.36817216]]
# [[0.70109165]]

# %%
for _ in range(epoch):
     # ---- Forward pass ----
    hidden_input = np.dot(inputs, weights_input_to_hidden) + bias_hidden
    hidden_output = activate(hidden_input)

    final_input = np.dot(hidden_output, weights_hidden_to_output) + bias_output
    predicted_output = activate(final_input)

    # ---- Calculate error ----
    output_error = targets - predicted_output

    # ---- Backpropagation ----
    output_gradient = output_error * activate_derivative(predicted_output)

    hidden_error = np.dot(output_gradient, weights_hidden_to_output.T)
    hidden_gradient = hidden_error * activate_derivative(hidden_output)

    # ---- Update weights ----
    weights_hidden_to_output += np.dot(hidden_output.T, output_gradient) * learning_rate
    weights_input_to_hidden += np.dot(inputs.T, hidden_gradient) * learning_rate

    # ---- Update biases ----
    bias_output += np.sum(output_gradient, axis=0, keepdims=True) * learning_rate
    bias_hidden += np.sum(hidden_gradient, axis=0, keepdims=True) * learning_rate
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 3
#       1 for _ in range(epoch):
#       2      # ---- Forward pass ----
# ----> 3     hidden_input = np.dot(inputs, weights_input_to_hidden) + bias_hidden
#       4     hidden_output = activate(hidden_input)
#       6     final_input = np.dot(hidden_output, weights_hidden_to_output) + bias_output
#
# ValueError: shapes (3,2) and (3,3) not aligned: 2 (dim 1) != 3 (dim 0)

# %%
print("\nInputs (normalized):")
print(inputs)

print("\nActual Marks:")
print(targets * 100)

print("\nPredicted Marks:")
print(predicted_output * 100)
# Out:
# Inputs (normalized):
# [[0.2        0.33333333]
#  [0.6        0.66666667]
#  [1.         1.        ]]
#
# Actual Marks:
# [[0.0007]
#  [0.0008]
#  [0.0009]]
#
# Predicted Marks:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 8
#       5 print(targets * 100)
#       7 print("\nPredicted Marks:")
# ----> 8 print(predicted_output * 100)
#
# NameError: name 'predicted_output' is not defined
